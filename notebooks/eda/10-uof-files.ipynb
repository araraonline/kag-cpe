# %% [markdown]
# # 10. Use-of-force (and other) files
#
# I will just take a look over all UOF files in this kernel.

# %%
import collections
import pandas

from cpe_help import list_departments

# %%
depts = list_departments()

# %%
[dept.full_name for dept in depts]
# Out:
# ['11-00091 (Boston, MA)',
#  '23-00089 (Lawrence, IN)',
#  '24-00013 (Minneapolis, MN)',
#  '24-00098 (St. Paul, MN)',
#  '35-00016 (Orlando, FL)',
#  '35-00103 (Charlotte, NC)',
#  '37-00027 (Austin, TX)',
#  '37-00049 (Dallas, TX)',
#  '49-00009 (Seattle, WA)',
#  '49-00033 (Los Angeles, CA)',
#  '49-00035 (Oakland, CA)',
#  '49-00081 (San Francisco, CA)']

# %%
files = []
for dept in depts:
    uofs = [x for x in dept.external_dir.iterdir() if x.is_file()]
    if uofs:
        files.append(uofs[0])
        # 1 per police dept
files
# Out:
# [PosixPath('/amnt/code/cpe/data/departments/11-00091/external/11-00091_Field-Interviews_2011-2015.csv'),
#  PosixPath('/amnt/code/cpe/data/departments/23-00089/external/23-00089_UOF-P.csv'),
#  PosixPath('/amnt/code/cpe/data/departments/24-00013/external/24-00013_UOF_2008-2017_prepped.csv'),
#  PosixPath('/amnt/code/cpe/data/departments/24-00098/external/24-00098_Vehicle-Stops-data.csv'),
#  PosixPath('/amnt/code/cpe/data/departments/35-00016/external/35-00016_UOF-OIS-P.csv'),
#  PosixPath('/amnt/code/cpe/data/departments/35-00103/external/35-00103_UOF-OIS-P_prepped.csv'),
#  PosixPath('/amnt/code/cpe/data/departments/37-00027/external/37-00027_UOF-P_2014-2016_prepped.csv'),
#  PosixPath('/amnt/code/cpe/data/departments/37-00049/external/37-00049_UOF-P_2016_prepped.csv'),
#  PosixPath('/amnt/code/cpe/data/departments/49-00009/external/49-00009_UOF.csv'),
#  PosixPath('/amnt/code/cpe/data/departments/49-00033/external/49-00033_Arrests_2015.csv'),
#  PosixPath('/amnt/code/cpe/data/departments/49-00035/external/49-00035_Incidents_2016.csv'),
#  PosixPath('/amnt/code/cpe/data/departments/49-00081/external/49-00081_Incident-Reports_2012_to_May_2015.csv')]

# %%
sum(file.stat().st_size for file in files) / 10 ** 6

# total size in MB -- okay for memory :D
# Out:
# 185.2544

# %%
frames = [pandas.read_csv(file, low_memory=False) for file in files]  # mixed dtype warning

# %% [markdown]
# # Quick glance

# %%
# field interviews
frames[0].head().T
# Out:
#                                                                  0  \
# INCIDENT_UNIQUE_IDENTIFIER                                 SEQ_NUM
# INCIDENT_UNIQUE_IDENTIFIER.1                                FIO_ID
# SUBJECT_GENDER                                                 SEX
# LOCATION_FULL_STREET_ADDRESS_OR_INTERSECTION              LOCATION
# LOCATION_DISTRICT                                             DIST
# LOCATION_DISTRICT.1                                        DIST_ID
# INCIDENT_DATE                                             FIO_DATE
# INCIDENT_TIME                                             FIO_TIME
# SUBJECT_DETAILS                                             PRIORS
# SUBJECT_RACE                                           DESCRIPTION
# SUBJECT_DETAILS.1                                         CLOTHING
# SUBJECT_DETAILS.2                                       COMPLEXION
# UNKNOWN_FIELD_TYPE                                      FIOFS_TYPE
# UNKNOWN_FIELD_TYPE.1                                     TERRORISM
# SEARCH_CONDUCTED                                            SEARCH
# SEARCH_REASON                                                BASIS
# INCIDENT_REASON                                       STOP_REASONS
# INCIDENT_REASON.1                                    FIOFS_REASONS
# DISPOSITION                                                OUTCOME
# VEHICLE_MAKE                                              VEH_MAKE
# VEHICLE_YEAR                                          VEH_YEAR_NUM
# VEHICLE_COLOR                                            VEH_COLOR
# VEHICLE_MODEL                                            VEH_MODEL
# VEHICLE_DETAILS                                       VEH_OCCUPANT
# VEHICLE_DETAILS.1                                        VEH_STATE
# OFFICER_SUPERVISOR                                   SUPERVISOR_ID
# OFFICER_ID                                              OFFICER_ID
# OFFICER_ASSIGNMENT                                     OFF_DIST_ID
# OFFICER_ASSIGNMENT.1                                      OFF_DIST
# OFFICER_ETHNICITY                                        ETHNICITY
# OFFICER_RACE                                             RACE_DESC
# OFFICER_AGE                                   AGE_AT_FIO_CORRECTED
# LOCATION_STREET_NUMBER                                   STREET_ID
# LOCATION_CITY                                                 CITY
#
#                                                                                             1  \
# INCIDENT_UNIQUE_IDENTIFIER                                                             938283
# INCIDENT_UNIQUE_IDENTIFIER.1                                                           621880
# SUBJECT_GENDER                                                                           MALE
# LOCATION_FULL_STREET_ADDRESS_OR_INTERSECTION                         NORMANDY ST at SUPPLE RD
# LOCATION_DISTRICT                                                                          B2
# LOCATION_DISTRICT.1                                                                         3
# INCIDENT_DATE                                                                   12/10/13 0:00
# INCIDENT_TIME                                                                   12/10/13 0:00
# SUBJECT_DETAILS                                                                           YES
# SUBJECT_RACE                                                                         B(Black)
# SUBJECT_DETAILS.1                             blk jacket, blk shirt, blue jeans, wht sneakers
# SUBJECT_DETAILS.2                                                                         Med
# UNKNOWN_FIELD_TYPE                                                                       IOFS
# UNKNOWN_FIELD_TYPE.1                                                                       NO
# SEARCH_CONDUCTED                                                                           VP
# SEARCH_REASON                                                                  CONSENT SEARCH
# INCIDENT_REASON                                                                 INVESTIGATIVE
# INCIDENT_REASON.1                                                        DRUGS, INVESTIGATION
# DISPOSITION                                                                               SFO
# VEHICLE_MAKE                                                                           NISSAN
# VEHICLE_YEAR                                                                             2012
# VEHICLE_COLOR                                                                          SILVER
# VEHICLE_MODEL                                                                             max
# VEHICLE_DETAILS                                                                        DRIVER
# VEHICLE_DETAILS.1                                                                          MA
# OFFICER_SUPERVISOR                                                                      10132
# OFFICER_ID                                                                              98656
# OFFICER_ASSIGNMENT                                                                       9999
# OFFICER_ASSIGNMENT.1                                                                    OTHER
# OFFICER_ETHNICITY                                                                         NaN
# OFFICER_RACE                                                                         B(Black)
# OFFICER_AGE                                                                                59
# LOCATION_STREET_NUMBER                                                                   3274
# LOCATION_CITY                                                                 NO DATA ENTERED
#
#                                                                         2  \
# INCIDENT_UNIQUE_IDENTIFIER                                         881897
# INCIDENT_UNIQUE_IDENTIFIER.1                                       565177
# SUBJECT_GENDER                                                       MALE
# LOCATION_FULL_STREET_ADDRESS_OR_INTERSECTION               75 BOYLSTON ST
# LOCATION_DISTRICT                                                      A1
# LOCATION_DISTRICT.1                                                     1
# INCIDENT_DATE                                                5/24/12 0:00
# INCIDENT_TIME                                                5/24/12 0:00
# SUBJECT_DETAILS                                                        NO
# SUBJECT_RACE                                                     W(White)
# SUBJECT_DETAILS.1                             GRY. SWEATSHIRT, BLUE JEANS
# SUBJECT_DETAILS.2                                                     Med
# UNKNOWN_FIELD_TYPE                                                     IO
# UNKNOWN_FIELD_TYPE.1                                                   NO
# SEARCH_CONDUCTED                                                      NaN
# SEARCH_REASON                                        REASONABLE SUSPICION
# INCIDENT_REASON                                                RADIO CALL
# INCIDENT_REASON.1                                       DRUGS, POSSESSION
# DISPOSITION                                                             F
# VEHICLE_MAKE                                              NO DATA ENTERED
# VEHICLE_YEAR                                                            0
# VEHICLE_COLOR                                             NO DATA ENTERED
# VEHICLE_MODEL                                                         NaN
# VEHICLE_DETAILS                                                       NaN
# VEHICLE_DETAILS.1                                         NO DATA ENTERED
# OFFICER_SUPERVISOR                                                   8949
# OFFICER_ID                                                           9765
# OFFICER_ASSIGNMENT                                                      1
# OFFICER_ASSIGNMENT.1                                                   A1
# OFFICER_ETHNICITY                                                     NaN
# OFFICER_RACE                                                     W(White)
# OFFICER_AGE                                                            26
# LOCATION_STREET_NUMBER                                                543
# LOCATION_CITY                                                       OTHER
#
#                                                                       3  \
# INCIDENT_UNIQUE_IDENTIFIER                                       882060
# INCIDENT_UNIQUE_IDENTIFIER.1                                     565340
# SUBJECT_GENDER                                                     MALE
# LOCATION_FULL_STREET_ADDRESS_OR_INTERSECTION               5 TOPLIFF ST
# LOCATION_DISTRICT                                                   C11
# LOCATION_DISTRICT.1                                                   5
# INCIDENT_DATE                                               6/4/12 0:00
# INCIDENT_TIME                                               6/4/12 0:00
# SUBJECT_DETAILS                                                     YES
# SUBJECT_RACE                                                   B(Black)
# SUBJECT_DETAILS.1                             GRY SWEATSHIRT, GRY PANTS
# SUBJECT_DETAILS.2                                                  Dark
# UNKNOWN_FIELD_TYPE                                                  IOF
# UNKNOWN_FIELD_TYPE.1                                                 NO
# SEARCH_CONDUCTED                                                    NaN
# SEARCH_REASON                                                       NaN
# INCIDENT_REASON                                         OTHER (SPECIFY)
# INCIDENT_REASON.1                                   INVESTIGATE, PERSON
# DISPOSITION                                                           F
# VEHICLE_MAKE                                            NO DATA ENTERED
# VEHICLE_YEAR                                                          0
# VEHICLE_COLOR                                           NO DATA ENTERED
# VEHICLE_MODEL                                                       NaN
# VEHICLE_DETAILS                                                     NaN
# VEHICLE_DETAILS.1                                       NO DATA ENTERED
# OFFICER_SUPERVISOR                                                11312
# OFFICER_ID                                                        83575
# OFFICER_ASSIGNMENT                                                   16
# OFFICER_ASSIGNMENT.1                                               YVSF
# OFFICER_ETHNICITY                                                   NaN
# OFFICER_RACE                                                   B(Black)
# OFFICER_AGE                                                          18
# LOCATION_STREET_NUMBER                                             4493
# LOCATION_CITY                                           NO DATA ENTERED
#
#                                                                          4
# INCIDENT_UNIQUE_IDENTIFIER                                          971623
# INCIDENT_UNIQUE_IDENTIFIER.1                                        653895
# SUBJECT_GENDER                                                        MALE
# LOCATION_FULL_STREET_ADDRESS_OR_INTERSECTION                 170 MORTON ST
# LOCATION_DISTRICT                                                       B2
# LOCATION_DISTRICT.1                                                      3
# INCIDENT_DATE                                                 6/21/14 0:00
# INCIDENT_TIME                                                 6/21/14 0:00
# SUBJECT_DETAILS                                                        YES
# SUBJECT_RACE                                                      B(Black)
# SUBJECT_DETAILS.1                             lime green shirt, blue jeans
# SUBJECT_DETAILS.2                                                      Med
# UNKNOWN_FIELD_TYPE                                                    IOFS
# UNKNOWN_FIELD_TYPE.1                                                    NO
# SEARCH_CONDUCTED                                                       NaN
# SEARCH_REASON                                                          NaN
# INCIDENT_REASON                                              INVESTIGATIVE
# INCIDENT_REASON.1                                                     ABDW
# DISPOSITION                                                              S
# VEHICLE_MAKE                                               NO DATA ENTERED
# VEHICLE_YEAR                                                             0
# VEHICLE_COLOR                                              NO DATA ENTERED
# VEHICLE_MODEL                                                          NaN
# VEHICLE_DETAILS                                                        NaN
# VEHICLE_DETAILS.1                                          NO DATA ENTERED
# OFFICER_SUPERVISOR                                                    9375
# OFFICER_ID                                                           76146
# OFFICER_ASSIGNMENT                                                      25
# OFFICER_ASSIGNMENT.1                                                  BIKE
# OFFICER_ETHNICITY                                                      NaN
# OFFICER_RACE                                                      B(Black)
# OFFICER_AGE                                                             24
# LOCATION_STREET_NUMBER                                                3094
# LOCATION_CITY                                                   Dorchester

# %%
# use of force
frames[2].head().T
# Out:
#                                              0                  1  \
# LOCATION_LONGITUDE                           X       -93.27169927
# LOCATION_LATITUDE                            Y        45.00803595
# INCIDENT_UNIQUE_IDENTIFIER  PoliceUseOfForceID                  1
# INCIDENT_DATE                     ResponseDate         2008-01-01
# INCIDENT_TIME                              NaN      01:15:31.000Z
# SUBJECT_INJURY                   SubjectInjury                 -1
# TYPE_OF_FORCE_USED             ForceTypeDetail    BodilyForceType
# WEAPON_OR_TOOL_USED            ForceTypeAction          Push Away
# SUBJECT_RACE                              Race              Black
# SUBJECT_GENDER                             Sex             Female
# SUBJECT_AGE                           EventAge                 25
# REASON_FOR_FORCE              TypeOfResistance  Assaulted Officer
# LOCATION_DISTRICT                     Precinct                  2
#
#                                              2                  3  \
# LOCATION_LONGITUDE                -93.27169927       -93.27169927
# LOCATION_LATITUDE                  45.00803595        45.00803595
# INCIDENT_UNIQUE_IDENTIFIER                   2                  3
# INCIDENT_DATE                       2008-01-01         2008-01-01
# INCIDENT_TIME                    01:15:31.000Z      01:15:31.000Z
# SUBJECT_INJURY                              -1                 -1
# TYPE_OF_FORCE_USED             BodilyForceType    BodilyForceType
# WEAPON_OR_TOOL_USED         Body Weight to Pin            Punches
# SUBJECT_RACE                             Black              Black
# SUBJECT_GENDER                          Female             Female
# SUBJECT_AGE                                 25                 25
# REASON_FOR_FORCE             Assaulted Officer  Assaulted Officer
# LOCATION_DISTRICT                            2                  2
#
#                                               4
# LOCATION_LONGITUDE                 -93.24701977
# LOCATION_LATITUDE                   44.95974418
# INCIDENT_UNIQUE_IDENTIFIER                    4
# INCIDENT_DATE                        2008-01-01
# INCIDENT_TIME                     01:27:27.000Z
# SUBJECT_INJURY                                0
# TYPE_OF_FORCE_USED              BodilyForceType
# WEAPON_OR_TOOL_USED                  Joint Lock
# SUBJECT_RACE                              White
# SUBJECT_GENDER                             Male
# SUBJECT_AGE                                  27
# REASON_FOR_FORCE            Commission of Crime
# LOCATION_DISTRICT                             3

# %%
# vehicle stops
frames[3].head().T
# Out:
#                                               0             1             2  \
# INCIDENT_DATE_YEAR                 YEAR OF STOP          2001          2001
# INCIDENT_DATE                      DATE OF STOP   1/1/01 0:11   1/1/01 0:14
# SUBJECT_RACE                     RACE OF DRIVER         White         White
# SUBJECT_GENDER                 GENDER OF DRIVER        Female          Male
# SEARCH_CONDUCTED_PERSON         DRIVER FRISKED?            No            No
# SEARCH_CONDUCTED_VEHICLE      VEHICLE SEARCHED?            No            No
# SUBJECT_ISSUED_CITATION        CITATION ISSUED?            No            No
# SUBJECT_AGE                       AGE OF DRIVER           NaN           NaN
# INCIDENT_REASON                 REASON FOR STOP       No Data       No Data
# LOCATION_DISTRICT            POLICE GRID NUMBER            55           106
# LOCATION_LATITUDE          LOCATION OF STOP LAT   44.97391713   44.95211807
# LOCATION_LONGITUDE        LOCATION OF STOP LONG  -93.06089457  -93.15173337
#
#                                      3             4
# INCIDENT_DATE_YEAR                2001          2001
# INCIDENT_DATE              1/1/01 0:23   1/1/01 0:28
# SUBJECT_RACE                     White         White
# SUBJECT_GENDER                    Male          Male
# SEARCH_CONDUCTED_PERSON             No            No
# SEARCH_CONDUCTED_VEHICLE            No            No
# SUBJECT_ISSUED_CITATION             No            No
# SUBJECT_AGE                        NaN           NaN
# INCIDENT_REASON                No Data       No Data
# LOCATION_DISTRICT                   58            44
# LOCATION_LATITUDE           44.9738881   44.97358832
# LOCATION_LONGITUDE        -93.03039075  -93.17215188

# %%
# officer-involved shootings
frames[4].head().T
# Out:
#                                                                         0  \
# INCIDENT_UNIQUE_IDENTIFIER                                         Case #
# INCIDENT_DATE                                                        Date
# LOCATION_FULL_STREET_ADDRESS_OR_INTERSECTION                      Address
# Unnamed: 3                                                  Incident Type
# NUMBER_OF_OFFICERS                            Number of Officers Involved
# OFFICER_RACE                                                 Officer Race
# OFFICER_ETHNICITY                                               Ethnicity
# OFFICER_GENDER                                             Officer Gender
# OFFICER_AGE                                                   Officer Age
# OFFICER_YEARS_ON_FORCE                                     Officer Tenure
# NUMBER_OF_SUBJECTS                            Number of Suspects Involved
# SUBJECT_RACE                                                 Suspect Race
# SUBJECT_GENDER                                             Suspect Gender
# SUBJECT_AGE                                                   Suspect Age
# SUBJECT_POSSESSED_WEAPON                                 Suspect's Weapon
# SUBJECT_INJURY                                                Suspect Hit
# SUBJECT_DEATH                                                       Fatal
# OFFICER_INJURY                                                Officer Hit
# OFFICER_DEATH                                             Fatal (Officer)
# LOCATION_LATITUDE                                                     Lat
# LOCATION_LONGITUDE                                                    Lon
#
#                                                                     1  \
# INCIDENT_UNIQUE_IDENTIFIER                                  16-179658
# INCIDENT_DATE                                                  5/1/16
# LOCATION_FULL_STREET_ADDRESS_OR_INTERSECTION  707 S Orange Blossom Tr
# Unnamed: 3                                              Armed Subject
# NUMBER_OF_OFFICERS                                                  2
# OFFICER_RACE                                                     W, W
# OFFICER_ETHNICITY                                                N, N
# OFFICER_GENDER                                                   M, M
# OFFICER_AGE                                                    28, 28
# OFFICER_YEARS_ON_FORCE                                           3, 1
# NUMBER_OF_SUBJECTS                                                  1
# SUBJECT_RACE                                                    Black
# SUBJECT_GENDER                                                      M
# SUBJECT_AGE                                                        25
# SUBJECT_POSSESSED_WEAPON                                      Handgun
# SUBJECT_INJURY                                                    Yes
# SUBJECT_DEATH                                                     Yes
# OFFICER_INJURY                                                 No, No
# OFFICER_DEATH                                                  No, No
# LOCATION_LATITUDE                                            28.53438
# LOCATION_LONGITUDE                                         -81.397105
#
#                                                                                        2  \
# INCIDENT_UNIQUE_IDENTIFIER                                                     16-242039
# INCIDENT_DATE                                                                    6/12/16
# LOCATION_FULL_STREET_ADDRESS_OR_INTERSECTION                          1912 S. Orange Ave
# Unnamed: 3                                                                Active Shooter
# NUMBER_OF_OFFICERS                                                                    11
# OFFICER_RACE                                              W,W, W, W, W, B, W, W, B, W, W
# OFFICER_ETHNICITY                                         N,N, N, N, N, H, N, N, N, N, H
# OFFICER_GENDER                                           M, M, M, M, M, M, M, M, M, M, M
# OFFICER_AGE                                   29, 39, 48, 46, 34, 45, 47, 44, 47, 38, 31
# OFFICER_YEARS_ON_FORCE                          4, 14, 25, 23, 11, 23, 18, 21, 21, 14, 2
# NUMBER_OF_SUBJECTS                                                                     1
# SUBJECT_RACE                                                                       Other
# SUBJECT_GENDER                                                                         M
# SUBJECT_AGE                                                                           29
# SUBJECT_POSSESSED_WEAPON                                                           Rifle
# SUBJECT_INJURY                                                                       Yes
# SUBJECT_DEATH                                                                        Yes
# OFFICER_INJURY                                Yes, No, No, No, No, No, No, No,No, No, No
# OFFICER_DEATH                                 No, No, No, No, No, No, No, No, No, No, No
# LOCATION_LATITUDE                                                              28.519553
# LOCATION_LONGITUDE                                                            -81.376362
#
#                                                                   3  \
# INCIDENT_UNIQUE_IDENTIFIER                                16-153523
# INCIDENT_DATE                                               4/13/16
# LOCATION_FULL_STREET_ADDRESS_OR_INTERSECTION  Bowen DR at Folkstone
# Unnamed: 3                                                  Battery
# NUMBER_OF_OFFICERS                                                1
# OFFICER_RACE                                                      W
# OFFICER_ETHNICITY                                                 H
# OFFICER_GENDER                                                    M
# OFFICER_AGE                                                      34
# OFFICER_YEARS_ON_FORCE                                            8
# NUMBER_OF_SUBJECTS                                                1
# SUBJECT_RACE                                                  White
# SUBJECT_GENDER                                                    M
# SUBJECT_AGE                                                      22
# SUBJECT_POSSESSED_WEAPON                                    Handgun
# SUBJECT_INJURY                                                  Yes
# SUBJECT_DEATH                                                    No
# OFFICER_INJURY                                                   No
# OFFICER_DEATH                                                    No
# LOCATION_LATITUDE                                         28.518123
# LOCATION_LONGITUDE                                       -81.306245
#
#                                                                  4
# INCIDENT_UNIQUE_IDENTIFIER                               16-025283
# INCIDENT_DATE                                              1/18/16
# LOCATION_FULL_STREET_ADDRESS_OR_INTERSECTION  6584 Swissco Dr #734
# Unnamed: 3                                        Well Being Check
# NUMBER_OF_OFFICERS                                               2
# OFFICER_RACE                                                  W, B
# OFFICER_ETHNICITY                                             H, N
# OFFICER_GENDER                                                M, F
# OFFICER_AGE                                                 41, 37
# OFFICER_YEARS_ON_FORCE                                        4, 5
# NUMBER_OF_SUBJECTS                                               1
# SUBJECT_RACE                                                 White
# SUBJECT_GENDER                                                   M
# SUBJECT_AGE                                                     28
# SUBJECT_POSSESSED_WEAPON                                   Handgun
# SUBJECT_INJURY                                                 Yes
# SUBJECT_DEATH                                                  Yes
# OFFICER_INJURY                                              No, No
# OFFICER_DEATH                                               No, No
# LOCATION_LATITUDE                                        28.469554
# LOCATION_LONGITUDE                                      -81.299363

# %%
# arrests
frames[9].head().T
# Out:
#                                                          0  \
# INCIDENT_DATE                                    ARST DATE
# INCIDENT_TIME                                         TIME
# INCIDENT_UNIQUE_IDENTIFIER                          RPT_ID
# LOCATION_DISTRICT                                     AREA
# LOCATION_TYPE                                    AREA_DESC
# UNKNOWN_FIELD_TYPE                                      RD
# SUBJECT_AGE                                            AGE
# SUBJECT_GENDER                                      SEX_CD
# SUBJECT_RACE                                    DESCENT_CD
# UNKNOWN_FIELD_TYPE.1                           CHRG_GRP_CD
# INCIDENT_REASON                                   GRP_DESC
# UNKNOWN_FIELD_TYPE.2                           ARST_TYP_CD
# CHARGE                                              CHARGE
# CHARGE_DESCRIPTION                               CHRG_DESC
# LOCATION_FULL_STREET_ADDRESS_OR_INTERSECTION      LOCATION
# CROSS_STREET                                         CRSST
# LOCATION_LATITUDE                             Location Lat
# LOCATION_LONGITUDE                            Location Lon
#
#                                                                                      1  \
# INCIDENT_DATE                                                            12/31/15 0:00
# INCIDENT_TIME                                                                     2345
# INCIDENT_UNIQUE_IDENTIFIER                                                     4538991
# LOCATION_DISTRICT                                                                   14
# LOCATION_TYPE                                                                  Pacific
# UNKNOWN_FIELD_TYPE                                                                1435
# SUBJECT_AGE                                                                         43
# SUBJECT_GENDER                                                                       M
# SUBJECT_RACE                                                                         H
# UNKNOWN_FIELD_TYPE.1                                                                22
# INCIDENT_REASON                                                Driving Under Influence
# UNKNOWN_FIELD_TYPE.2                                                                 M
# CHARGE                                                                      23152(A)VC
# CHARGE_DESCRIPTION                                         DRUNK DRIVING ALCOHOL/DRUGS
# LOCATION_FULL_STREET_ADDRESS_OR_INTERSECTION   3500    MCLAUGHLIN                   AV
# CROSS_STREET                                                                       NaN
# LOCATION_LATITUDE                                                              34.0141
# LOCATION_LONGITUDE                                                           -118.4288
#
#                                                                                      2  \
# INCIDENT_DATE                                                            12/31/15 0:00
# INCIDENT_TIME                                                                     2330
# INCIDENT_UNIQUE_IDENTIFIER                                                     4538996
# LOCATION_DISTRICT                                                                    1
# LOCATION_TYPE                                                                  Central
# UNKNOWN_FIELD_TYPE                                                                 101
# SUBJECT_AGE                                                                         27
# SUBJECT_GENDER                                                                       M
# SUBJECT_RACE                                                                         W
# UNKNOWN_FIELD_TYPE.1                                                                 4
# INCIDENT_REASON                                                     Aggravated Assault
# UNKNOWN_FIELD_TYPE.2                                                                 F
# CHARGE                                                                      273.5(A)PC
# CHARGE_DESCRIPTION                            CORPORAL INJURY ON SPOUSE/COHABITANT/ETC
# LOCATION_FULL_STREET_ADDRESS_OR_INTERSECTION    900    FIGUEROA                     TR
# CROSS_STREET                                                                       NaN
# LOCATION_LATITUDE                                                              34.0663
# LOCATION_LONGITUDE                                                           -118.2441
#
#                                                                                      3  \
# INCIDENT_DATE                                                            12/31/15 0:00
# INCIDENT_TIME                                                                     2320
# INCIDENT_UNIQUE_IDENTIFIER                                                     4539142
# LOCATION_DISTRICT                                                                    6
# LOCATION_TYPE                                                                Hollywood
# UNKNOWN_FIELD_TYPE                                                                 646
# SUBJECT_AGE                                                                         31
# SUBJECT_GENDER                                                                       M
# SUBJECT_RACE                                                                         W
# UNKNOWN_FIELD_TYPE.1                                                                16
# INCIDENT_REASON                                                     Narcotic Drug Laws
# UNKNOWN_FIELD_TYPE.2                                                                 M
# CHARGE                                                                      11350(A)HS
# CHARGE_DESCRIPTION                                  POSSESSION OF CONTROLLED SUBSTANCE
# LOCATION_FULL_STREET_ADDRESS_OR_INTERSECTION   6300    HOLLYWOOD                    BL
# CROSS_STREET                                                                       NaN
# LOCATION_LATITUDE                                                              34.1016
# LOCATION_LONGITUDE                                                           -118.3267
#
#                                                                                      4
# INCIDENT_DATE                                                            12/31/15 0:00
# INCIDENT_TIME                                                                     2319
# INCIDENT_UNIQUE_IDENTIFIER                                                     4538947
# LOCATION_DISTRICT                                                                   21
# LOCATION_TYPE                                                                  Topanga
# UNKNOWN_FIELD_TYPE                                                                2189
# SUBJECT_AGE                                                                         28
# SUBJECT_GENDER                                                                       M
# SUBJECT_RACE                                                                         H
# UNKNOWN_FIELD_TYPE.1                                                                22
# INCIDENT_REASON                                                Driving Under Influence
# UNKNOWN_FIELD_TYPE.2                                                                 M
# CHARGE                                                                      23152(A)VC
# CHARGE_DESCRIPTION                                         DRUNK DRIVING ALCOHOL/DRUGS
# LOCATION_FULL_STREET_ADDRESS_OR_INTERSECTION           VENTURA                      FY
# CROSS_STREET                                                                  WINNETKA
# LOCATION_LATITUDE                                                              34.1723
# LOCATION_LONGITUDE                                                           -118.5709

# %%
# incidents
frames[10].head().T
# Out:
#                                                         0  \
# CRIME_TYPE                                      CrimeType
# INCIDENT_DATE                                    DateTime
# INCIDENT_UNIQUE_IDENTIFIER                     CaseNumber
# INCIDENT_REASON                               Description
# LOCATION_DISTRICT                              PoliceBeat
# LOCATION_FULL_STREET_ADDRESS_OR_INTERSECTION      Address
# LOCATION_CITY                                        City
# LOCATION_STATE                                      State
#
#                                                                          1  \
# CRIME_TYPE                                               DOMESTIC VIOLENCE
# INCIDENT_DATE                                                12/6/16 16:12
# INCIDENT_UNIQUE_IDENTIFIER                                       16-064496
# INCIDENT_REASON                                 THREAT CRIME:INT:TERRORIZE
# LOCATION_DISTRICT                                                      04X
# LOCATION_FULL_STREET_ADDRESS_OR_INTERSECTION  1700 MARTIN LUTHER KING JR W
# LOCATION_CITY                                                      Oakland
# LOCATION_STATE                                                          CA
#
#                                                                  2  \
# CRIME_TYPE                                          STOLEN VEHICLE
# INCIDENT_DATE                                         12/6/16 7:20
# INCIDENT_UNIQUE_IDENTIFIER                               16-064497
# INCIDENT_REASON                               VEHICLE THEFT - AUTO
# LOCATION_DISTRICT                                              27X
# LOCATION_FULL_STREET_ADDRESS_OR_INTERSECTION          1600 HIGH ST
# LOCATION_CITY                                              Oakland
# LOCATION_STATE                                                  CA
#
#                                                                                               3  \
# CRIME_TYPE                                                                       FELONY ASSAULT
# INCIDENT_DATE                                                                     12/6/16 19:00
# INCIDENT_UNIQUE_IDENTIFIER                                                            16-064499
# INCIDENT_REASON                               OBSTRUCT/RESIST/ETC PUBLIC/PEACE OFFICER/EMERG...
# LOCATION_DISTRICT                                                                           08X
# LOCATION_FULL_STREET_ADDRESS_OR_INTERSECTION                                  2800 TELEGRAPH AV
# LOCATION_CITY                                                                           Oakland
# LOCATION_STATE                                                                               CA
#
#                                                                                        4
# CRIME_TYPE                                                                     NARCOTICS
# INCIDENT_DATE                                                              12/6/16 19:20
# INCIDENT_UNIQUE_IDENTIFIER                                                     16-064501
# INCIDENT_REASON                               POSSESS CONTROLLED SUBSTANCE PARAPHERNALIA
# LOCATION_DISTRICT                                                                    07X
# LOCATION_FULL_STREET_ADDRESS_OR_INTERSECTION                         34TH ST & LINDEN ST
# LOCATION_CITY                                                                    Oakland
# LOCATION_STATE                                                                        CA

# %% [markdown]
# # General info
#
# - There are **12 departments** (related to [report][1]?)
# - Number of entries vary a lot (55 to 710k)
# - 15 columns (median)
#
# # Types of data
#
# - Use of force (UOF) - 5 departments
# - Officer-involved shootings (OIS) - 2 departments
# - [Incidents][12] - 2 departments
# - Vehicle stops - 1 department
# - [Field interviews][11] - 1 department
# - Arrests - 1 department
#
# # Some findings
#
# - All datasets come with the `INCIDENT_DATE` column (different formats)
# - The `LOCATION` indicator comes in the most varied forms
# - The variables are not totally cleaned (e.g. check `SUBJECT_RACT` column in Lawrence)
# - Lots of checks/preparation will still need to be made if we want to automate things (these checks and preparation themselves may be partially automated)
#
# [1]: http://policingequity.org/wp-content/uploads/2016/07/CPE_SoJ_Race-Arrests-UoF_2016-07-08-1130.pdf
# [11]: https://bizfluent.com/info-8223154-field-interview.html
# [12]: https://www.policedatainitiative.org/datasets/incidents/

# %%
overall = pandas.DataFrame({
    'dept': depts,
    'dept_full_name': [d.full_name for d in depts],
    'dept_name': [d.name for d in depts],
    'dept_loc': [d.location for d in depts],
    'file_name': [f.name for f in files],
    'dframe': frames,
    'ncolumns': [f.shape[1] for f in frames],
    'nrows': [f.shape[0] for f in frames]
})
overall
# Out:
#                              dept                dept_full_name dept_name  \
# 0          Department('11-00091')         11-00091 (Boston, MA)  11-00091
# 1          Department('23-00089')       23-00089 (Lawrence, IN)  23-00089
# 2          Department('24-00013')    24-00013 (Minneapolis, MN)  24-00013
# 3          Department('24-00098')       24-00098 (St. Paul, MN)  24-00098
# 4   Department3500016('35-00016')        35-00016 (Orlando, FL)  35-00016
# 5   Department3500103('35-00103')      35-00103 (Charlotte, NC)  35-00103
# 6   Department3700027('37-00027')         37-00027 (Austin, TX)  37-00027
# 7          Department('37-00049')         37-00049 (Dallas, TX)  37-00049
# 8          Department('49-00009')        49-00009 (Seattle, WA)  49-00009
# 9          Department('49-00033')    49-00033 (Los Angeles, CA)  49-00033
# 10         Department('49-00035')        49-00035 (Oakland, CA)  49-00035
# 11         Department('49-00081')  49-00081 (San Francisco, CA)  49-00081
#
#              dept_loc                                       file_name  \
# 0          Boston, MA         11-00091_Field-Interviews_2011-2015.csv
# 1        Lawrence, IN                              23-00089_UOF-P.csv
# 2     Minneapolis, MN              24-00013_UOF_2008-2017_prepped.csv
# 3        St. Paul, MN                 24-00098_Vehicle-Stops-data.csv
# 4         Orlando, FL                          35-00016_UOF-OIS-P.csv
# 5       Charlotte, NC                  35-00103_UOF-OIS-P_prepped.csv
# 6          Austin, TX            37-00027_UOF-P_2014-2016_prepped.csv
# 7          Dallas, TX                 37-00049_UOF-P_2016_prepped.csv
# 8         Seattle, WA                                49-00009_UOF.csv
# 9     Los Angeles, CA                       49-00033_Arrests_2015.csv
# 10        Oakland, CA                     49-00035_Incidents_2016.csv
# 11  San Francisco, CA  49-00081_Incident-Reports_2012_to_May_2015.csv
#
#                                                dframe  ncolumns   nrows
# 0          INCIDENT_UNIQUE_IDENTIFIER INCIDENT_UNI...        34  152231
# 1                INCIDENT_UNIQUE_IDENTIFIER  INCID...        26   10275
# 2         LOCATION_LONGITUDE LOCATION_LATITUDE INC...        13   25802
# 3          INCIDENT_DATE_YEAR   INCIDENT_DATE    S...        12  710473
# 4      INCIDENT_UNIQUE_IDENTIFIER INCIDENT_DATE  \...        21      55
# 5      INCIDENT_UNIQUE_IDENTIFIER INCIDENT_DATE   ...         9      78
# 6            RIN  PRIMARY_KEY  INCIDENT_DATE LOCAT...        29    9483
# 7        INCIDENT_DATE INCIDENT_TIME  \
# 0       OC...        47    2384
# 8        INCIDENT_UNIQUE_IDENTIFIER INCIDENT_UNIQU...        11    8688
# 9           INCIDENT_DATE INCIDENT_TIME INCIDENT_U...        18  126855
# 10                 CRIME_TYPE   INCIDENT_DATE INCI...         8   10770
# 11         INCIDENT_UNIQUE_IDENTIFIER             ...        11  394236

# %% [markdown]
# ## Use of force (UOF)
#
# ### General characteristics
#
# - Present in 5 departments
#   - 23-00089 (Lawrence, IN)
#   - 24-00013 (Minneapolis, MN) (2008-2017)
#   - 37-00027 (Austin, TX) (2014-2016)
#   - 37-00049 (Dallas, TX) (2016)
#   - 49-00009 (Seattle, WA)
# - 11 to 47 variables
# - 2384 to 25802 entries
#
# ### Normalized Variable Groups
#
# *variables in bold appeared in at least 4 of the 5 datasets*
#
# #### Incident
#
# - **`INCIDENT_DATE`**
# - `INCIDENT_REASON`
# - `INCIDENT_TIME`
# - `INCIDENT_UNIQUE)IDENTIFIER.1`
# - `INCIDENT_UNIQUE_IDENTIFIER`
#
# #### Location
#
# - `LOCATION_CITY`
# - **`LOCATION_DISTRICT`**
# - `LOCATION_DISTRICT.1`
# - `LOCATION_DISTRICT.2`
# - `LOCATION_FULL_STREET_ADDRESS_OR_INTERSECTION`
# - `LOCATION_LATITUDE`
# - `LOCATION_LONGITUDE`
# - `LOCATION_STATE`
#
# #### Officer
#
# - `OFFICER_AGE`
# - `OFFICER_ASSIGNMENT`
# - `OFFICER_DETAILS`
# - `OFFICER_GENDER`
# - `OFFICER_HIRE_DATE`
# - `OFFICER_HOSPITALIZATION`
# - `OFFICER_ID`
# - `OFFICER_INJURY`
# - `OFFICER_INJURY_TYPE`
# - `OFFICER_RACE`
# - `OFFICER_YEARS_ON_FORCE`
#
# #### Street
#
# - `STREET_DIRECTION`
# - `STREET_NAME`
# - `STREET_NUMBER`
# - `STREET_TYPE`
#
# #### Subject
#
# - `SUBJECT_AGE`
# - `SUBJECT_DESCRIPTION`
# - `SUBJECT_DETAILS`
# - `SUBJECT_DETAILS.1`
# - **`SUBJECT_GENDER`**
# - `SUBJECT_HOSPITALIZATION`
# - `SUBJECT_ID`
# - `SUBJECT_INJURY`
# - `SUBJECT_INJURY_TYPE`
# - `SUBJECT_OFFENSE`
# - **`SUBJECT_RACE`**
# - `SUBJECT_RACT`
# - `SUBJECT_ROLE`
# - `SUBJECT_WAS_ARRESTED`
#
# #### Type of force used
#
# - `TYPE_OF_FORCE_USED`
# - `TYPE_OF_FORCE_USED1`
# - `TYPE_OF_FORCE_USED10`
# - `TYPE_OF_FORCE_USED2`
# - `TYPE_OF_FORCE_USED3`
# - `TYPE_OF_FORCE_USED4`
# - `TYPE_OF_FORCE_USED5`
# - `TYPE_OF_FORCE_USED6`
# - `TYPE_OF_FORCE_USED7`
# - `TYPE_OF_FORCE_USED8`
# - `TYPE_OF_FORCE_USED9`
#
# #### Others
#
# - `BEAT`
# - `CHARGE`
# - `DIVISION`
# - `FORCE_EFFECTIVE`
# - `NUMBER_EC_CYCLES`
# - `PRIMARY_KEY`
# - **`REASON_FOR_FORCE`**
# - `REASON_FOR_FORCE.1`
# - `REPORTING_AREA`
# - `RIN`
# - `SECTOR`
# - `SHIFT`
# - `UOF_NUMBER`
# - `Unnamed: 19 (Officer Organization Desc)`
# - `WEAPON_OR_TOOL_USED`
# - `Y_COORDINATE`
# - `Y_COORDINATE.1`

# %%
overall.loc[[1, 2, 6, 7, 8]]
# Out:
#                             dept              dept_full_name dept_name  \
# 1         Department('23-00089')     23-00089 (Lawrence, IN)  23-00089
# 2         Department('24-00013')  24-00013 (Minneapolis, MN)  24-00013
# 6  Department3700027('37-00027')       37-00027 (Austin, TX)  37-00027
# 7         Department('37-00049')       37-00049 (Dallas, TX)  37-00049
# 8         Department('49-00009')      49-00009 (Seattle, WA)  49-00009
#
#           dept_loc                             file_name  \
# 1     Lawrence, IN                    23-00089_UOF-P.csv
# 2  Minneapolis, MN    24-00013_UOF_2008-2017_prepped.csv
# 6       Austin, TX  37-00027_UOF-P_2014-2016_prepped.csv
# 7       Dallas, TX       37-00049_UOF-P_2016_prepped.csv
# 8      Seattle, WA                      49-00009_UOF.csv
#
#                                               dframe  ncolumns  nrows
# 1               INCIDENT_UNIQUE_IDENTIFIER  INCID...        26  10275
# 2        LOCATION_LONGITUDE LOCATION_LATITUDE INC...        13  25802
# 6           RIN  PRIMARY_KEY  INCIDENT_DATE LOCAT...        29   9483
# 7       INCIDENT_DATE INCIDENT_TIME  \
# 0       OC...        47   2384
# 8       INCIDENT_UNIQUE_IDENTIFIER INCIDENT_UNIQU...        11   8688

# %%
uof_frames = overall.loc[[1, 2, 6, 7, 8], 'dframe']
variables1 = sorted(set(c for df in uof_frames for c in df.columns))
variables2 = sorted(set(c for df in uof_frames for c in df.iloc[0] if not isinstance(c, float)))  # not prepped

# %%
collections.Counter(c for df in uof_frames for c in df.columns).most_common()[:5]
# Out:
# [('INCIDENT_DATE', 5),
#  ('LOCATION_DISTRICT', 5),
#  ('SUBJECT_GENDER', 5),
#  ('REASON_FOR_FORCE', 4),
#  ('SUBJECT_RACE', 4)]

# %% [markdown]
# ## Officer-involved shootings
#
# ### General characteristics
#
# - Present in 2 departments
#   - 35-00016 (Orlando, FL)
#   - 35-00103 (Charlotte, NC)
# - 9 and 21 variables
# - 55 and 78 entries
#
# ### Normalized Variable Groups
#
# *variables in bold appeared in both datasets*
#
# #### Incident
#
# - **`INCIDENT_DATE`**
# - **`INCIDENT_UNIQUE_IDENTIFIER`**
#
# #### Location
#
# - **`LOCATION_FULL_STREET_ADDRESS_OR_INTERSECTION`**
# - **`LOCATION_LATITUDE`**
# - **`LOCATION_LONGITUDE`**
#
# #### Officer
#
# - `OFFICER_AGE`
# - `OFFICER_DEATH`
# - `OFFICER_ETHNICITY`
# - `OFFICER_GENDER`
# - `OFFICER_INJURY`
# - `OFFICER_RACE`
# - `OFFICER_YEARS_ON_FORCE`
#
# #### Subject
#
# - `SUBJECT_AGE`
# - `SUBJECT_AGE_IN_YEARS`
# - `SUBJECT_DEATH`
# - **`SUBJECT_GENDER`**
# - `SUBJECT_INJURY`
# - `SUBJECT_INJURY_TYPE`
# - `SUBJECT_POSSESSED_WEAPON`
# - **`SUBJECT_RACE`**
#
# #### Others
#
# - `NUMBER_OF_OFFICERS`
# - `NUMBER_OF_SUBJECTS`
# - `Unnamed: 3 (Incident Type)`

# %%
overall.loc[[4, 5]]
# Out:
#                             dept            dept_full_name dept_name  \
# 4  Department3500016('35-00016')    35-00016 (Orlando, FL)  35-00016
# 5  Department3500103('35-00103')  35-00103 (Charlotte, NC)  35-00103
#
#         dept_loc                       file_name  \
# 4    Orlando, FL          35-00016_UOF-OIS-P.csv
# 5  Charlotte, NC  35-00103_UOF-OIS-P_prepped.csv
#
#                                               dframe  ncolumns  nrows
# 4     INCIDENT_UNIQUE_IDENTIFIER INCIDENT_DATE  \...        21     55
# 5     INCIDENT_UNIQUE_IDENTIFIER INCIDENT_DATE   ...         9     78

# %%
ois_frames = overall.loc[[4, 5], 'dframe']
variables1 = sorted(set(c for df in ois_frames for c in df.columns))
variables2 = sorted(set(c for df in ois_frames for c in df.iloc[0] ))  # not prepped

# %%
collections.Counter(c for df in ois_frames for c in df.columns).most_common()[:7]
# Out:
# [('INCIDENT_UNIQUE_IDENTIFIER', 2),
#  ('INCIDENT_DATE', 2),
#  ('LOCATION_FULL_STREET_ADDRESS_OR_INTERSECTION', 2),
#  ('SUBJECT_RACE', 2),
#  ('SUBJECT_GENDER', 2),
#  ('LOCATION_LATITUDE', 2),
#  ('LOCATION_LONGITUDE', 2)]

# %% [markdown]
# ## Incidents
#
# ### General characteristics
#
# - Present in 2 departments
#   - 49-00035 (Oakland, CA) (2016)
#   - 49-00081 (San Francisco, CA) (2012-2015)
# - 8 and 11 variables
# - 10770 and 394236 entries
#
# ### Normalized Variable Groups
#
# *variables in bold appeared in both datasets*
#
# #### Incident
#
# - **`INCIDENT_DATE`**
# - `INCIDENT_DAY`
# - **`INCIDENT_REASON`**
# - `INCIDENT_REASON_DESCRIPTION`
# - `INCIDENT_TIME`
# - **`INCIDENT_UNIQUE_IDENTIFIER`**
#
# #### Location
#
# - `LOCATION_CITY`
# - **`LOCATION_DISTRICT`**
# - **`LOCATION_FULL_STREET_ADDRESS_OR_INTERSECTION`**
# - `LOCATION_LATITUDE`
# - `LOCATION_LONGITUDE`
# - `LOCATION_STATE`
#
# #### Others
#
# - `CRIME_TYPE`
# - `DISPOSITION`

# %%
overall.loc[[10, 11]]
# Out:
#                       dept                dept_full_name dept_name  \
# 10  Department('49-00035')        49-00035 (Oakland, CA)  49-00035
# 11  Department('49-00081')  49-00081 (San Francisco, CA)  49-00081
#
#              dept_loc                                       file_name  \
# 10        Oakland, CA                     49-00035_Incidents_2016.csv
# 11  San Francisco, CA  49-00081_Incident-Reports_2012_to_May_2015.csv
#
#                                                dframe  ncolumns   nrows
# 10                 CRIME_TYPE   INCIDENT_DATE INCI...         8   10770
# 11         INCIDENT_UNIQUE_IDENTIFIER             ...        11  394236

# %%
inc_frames = overall.loc[[10, 11], 'dframe']
variables1 = sorted(set(c for df in inc_frames for c in df.columns))
variables2 = sorted(set(c for df in inc_frames for c in df.iloc[0]))  # not prepped

# %%
collections.Counter(c for df in inc_frames for c in df.columns).most_common()[:5]
# Out:
# [('INCIDENT_DATE', 2),
#  ('INCIDENT_UNIQUE_IDENTIFIER', 2),
#  ('INCIDENT_REASON', 2),
#  ('LOCATION_DISTRICT', 2),
#  ('LOCATION_FULL_STREET_ADDRESS_OR_INTERSECTION', 2)]

# %% [markdown]
# ## Vehicle stops
#
# ### General characteristics
#
# - Present in department 24-00098 (St. Paul, MN)
# - 12 variables
# - 710437 entries
#
# ### Variable Groups
#
# #### Incident
#
# - `INCIDENT_DATE`
# - `INCIDENT_DATE_YEAR`
# - `INCIDENT_REASON`
#
# #### Location
#
# - `LOCATION_DISTRICT`
# - `LOCATION_LATITUDE`
# - `LOCATION_LONGITUDE`
#
# #### Search conducted?
#
# - `SEARCH_CONDUCTED_PERSON`
# - `SEARCH_CONDUCTED_VEHICLE`
#
# #### Subject
#
# - `SUBJECT_AGE`
# - `SUBJECT_GENDER`
# - `SUBJECT_ISSUED_CITATION`
# - `SUBJECT_RACE`

# %%
overall.loc[[3]]
# Out:
#                      dept           dept_full_name dept_name      dept_loc  \
# 3  Department('24-00098')  24-00098 (St. Paul, MN)  24-00098  St. Paul, MN
#
#                          file_name  \
# 3  24-00098_Vehicle-Stops-data.csv
#
#                                               dframe  ncolumns   nrows
# 3         INCIDENT_DATE_YEAR   INCIDENT_DATE    S...        12  710473

# %%
veh_df = overall.loc[3, 'dframe']
variables1 = sorted(veh_df.columns)
variables2 = sorted(veh_df.iloc[0])

# %% [markdown]
# ## Field interviews
#
# ### General characteristics
#
# - Present in department 11-00091 (Boston, MA) (2011-2015)
# - 34 variables
# - 152231 entries
#
# ### Variable Groups
#
# #### Incident
#
# - `INCIDENT_DATE`
# - `INCIDENT_REASON`
# - `INCIDENT_REASON.1`
# - `INCIDENT_TIME`
# - `INCIDENT_UNIQUE_IDENTIFIER`
# - `INCIDENT_UNIQUE_IDENTIFIER.1`
#
# #### Location
#
# - `LOCATION_CITY`
# - `LOCATION_DISTRICT`
# - `LOCATION_DISTRICT.1`
# - `LOCATION_FULL_STREET_ADDRESS_OR_INTERSECTION`
# - `LOCATION_STREET_NUMBER`
#
# #### Officer
#
# - `OFFICER_AGE`
# - `OFFICER_ASSIGNMENT`
# - `OFFICER_ASSIGNMENT.1`
# - `OFFICER_ETHNICITY`
# - `OFFICER_ID`
# - `OFFICER_RACE`
# - `OFFICER_SUPERVISOR`
#
# #### Subject
#
# - `SUBJECT_DETAILS`
# - `SUBJECT_DETAILS.1`
# - `SUBJECT_DETAILS.2`
# - `SUBJECT_GENDER`
# - `SUBJECT_RACE`
#
# #### Vehicle
#
# - `VEHICLE_COLOR`
# - `VEHICLE_DETAILS`
# - `VEHICLE_DETAILS.1`
# - `VEHICLE_MAKE`
# - `VEHICLE_MODEL`
# - `VEHICLE_YEAR`
#
# #### Others
#
# - `DISPOSITION`
# - `SEARCH_CONDUCTED`
# - `SEARCH_REASON`
# - `UNKNOWN_FIELD_TYPE (FIOFS_TYPE)`
# - `UNKNOWN_FIELD_TYPE.1 (TERRORISM)`

# %%
overall.loc[[0]]
# Out:
#                      dept         dept_full_name dept_name    dept_loc  \
# 0  Department('11-00091')  11-00091 (Boston, MA)  11-00091  Boston, MA
#
#                                  file_name  \
# 0  11-00091_Field-Interviews_2011-2015.csv
#
#                                               dframe  ncolumns   nrows
# 0         INCIDENT_UNIQUE_IDENTIFIER INCIDENT_UNI...        34  152231

# %%
fi_df = overall.loc[0, 'dframe']
variables1 = sorted(fi_df.columns)
variables2 = sorted(fi_df.iloc[0])

# %% [markdown]
# ## Arrests
#
# ### General characteristics
#
# - Present in department 49-00033 (Los Angeles, CA) (2015)
# - 18 variables
# - 126855 entries
#
# Ref (search for the var name):
#
# https://github.com/CityOfLosAngeles/pd-geohub-migration/blob/master/arrests.py
#
# ### Variable Groups
#
# #### Charge
#
# - `CHARGE`
# - `CHARGE_DESCRIPTION`
#
# #### Incident
#
# - `INCIDENT_DATE`
# - `INCIDENT_REASON`
# - `INCIDENT_TIME`
# - `INCIDENT_UNIQUE_IDENTIFIER`
#
# #### Location
#
# - `LOCATION_DISTRICT`
# - `LOCATION_FULL_STREET_ADDRESS_OR_INTERSECTION`
# - `LOCATION_LATITUDE`
# - `LOCATION_LONGITUDE`
# - `LOCATION_TYPE`
#
# #### Subject
#
# - `SUBJECT_AGE`
# - `SUBJECT_GENDER`
# - `SUBJECT_RACE`
#
# #### Others
#
# - `CROSS_STREET`
# - `UNKNOWN_FIELD_TYPE (RD)`
# - `UNKNOWN_FIELD_TYPE.1 (CHRG_GRP_CD)`
# - `UNKNOWN_FIELD_TYPE.2 (ARST_TYP_CD)`

# %%
overall.loc[[9]]
# Out:
#                      dept              dept_full_name dept_name  \
# 9  Department('49-00033')  49-00033 (Los Angeles, CA)  49-00033
#
#           dept_loc                  file_name  \
# 9  Los Angeles, CA  49-00033_Arrests_2015.csv
#
#                                               dframe  ncolumns   nrows
# 9          INCIDENT_DATE INCIDENT_TIME INCIDENT_U...        18  126855

# %%
arr_df = overall.loc[9, 'dframe']
variables1 = sorted(arr_df.columns)
variables2 = sorted(arr_df.iloc[0])
