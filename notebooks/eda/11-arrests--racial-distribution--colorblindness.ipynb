# %% [markdown]
# # 11. Arrests / Los Angeles demographics - Racial Distribution - Colorblindness
#
# This notebook will perform an EDA over the Department 49-00033 (Los Angeles, CA) arrests and demographics.
#
# A hope is that this will provide some insights and experience into plotting tools, e.g. folium and holoviews, and that it may also give some insights into the data and how it should be wrangled. Hope for the best (:
#
# # Racial Distribtion
#
# In this I will try to visualize the racial distribution of LA. The best way to do this seem to be using a racial dot map. Let's do it!
#
# # Colorblindness
#
# The color scheme for the racial dot map probably came from the ArcMap Standard Pallete ([ref][1]). I couldn't make a qualitative map with 5 colors distinguishable enough for myself. I could, however, make one using 4 colors of the Paired pallete. This made me drop the 'Other' category.
#
# While the result is readable, the map doesn't look good. I'm beginning to think that it may be wise to drop the racial map altogether!
#
# [1]: http://www.eykamp.com/gistools/colors/index.htm

# %% [markdown]
# # Load data

# %%
import collections

import folium
import folium.plugins
import geopandas
import matplotlib.lines
import matplotlib.pyplot
import numpy
import pandas
import seaborn
import shapely

from cpe_help import Department, util

# %%
dept = Department('49-00033')
dept
# Out:
# Department4900033('49-00033')

# %% [markdown]
# ## Arrests

# %%
# !ls {dept.external_dir}
# Out:
# ls: cannot access '{dept.external_dir}': No such file or directory

# %%
raw_arrests = pandas.read_csv(dept.tabular_input_dir / '49-00033_Arrests_2015.csv', low_memory=False)
raw_arrests.head()
# Out:
#    INCIDENT_DATE INCIDENT_TIME INCIDENT_UNIQUE_IDENTIFIER LOCATION_DISTRICT  \
# 0      ARST DATE          TIME                     RPT_ID              AREA
# 1  12/31/15 0:00          2345                    4538991                14
# 2  12/31/15 0:00          2330                    4538996                 1
# 3  12/31/15 0:00          2320                    4539142                 6
# 4  12/31/15 0:00          2319                    4538947                21
#
#   LOCATION_TYPE UNKNOWN_FIELD_TYPE SUBJECT_AGE SUBJECT_GENDER SUBJECT_RACE  \
# 0     AREA_DESC                 RD         AGE         SEX_CD   DESCENT_CD
# 1       Pacific               1435          43              M            H
# 2       Central                101          27              M            W
# 3     Hollywood                646          31              M            W
# 4       Topanga               2189          28              M            H
#
#   UNKNOWN_FIELD_TYPE.1          INCIDENT_REASON UNKNOWN_FIELD_TYPE.2  \
# 0          CHRG_GRP_CD                 GRP_DESC          ARST_TYP_CD
# 1                   22  Driving Under Influence                    M
# 2                    4       Aggravated Assault                    F
# 3                   16       Narcotic Drug Laws                    M
# 4                   22  Driving Under Influence                    M
#
#        CHARGE                        CHARGE_DESCRIPTION  \
# 0      CHARGE                                 CHRG_DESC
# 1  23152(A)VC               DRUNK DRIVING ALCOHOL/DRUGS
# 2  273.5(A)PC  CORPORAL INJURY ON SPOUSE/COHABITANT/ETC
# 3  11350(A)HS        POSSESSION OF CONTROLLED SUBSTANCE
# 4  23152(A)VC               DRUNK DRIVING ALCOHOL/DRUGS
#
#   LOCATION_FULL_STREET_ADDRESS_OR_INTERSECTION CROSS_STREET LOCATION_LATITUDE  \
# 0                                     LOCATION        CRSST      Location Lat
# 1      3500    MCLAUGHLIN                   AV          NaN           34.0141
# 2       900    FIGUEROA                     TR          NaN           34.0663
# 3      6300    HOLLYWOOD                    BL          NaN           34.1016
# 4              VENTURA                      FY     WINNETKA           34.1723
#
#   LOCATION_LONGITUDE
# 0       Location Lon
# 1          -118.4288
# 2          -118.2441
# 3          -118.3267
# 4          -118.5709

# %% [markdown]
# ## Block groups + precincts + census tracts

# %%
bgs = dept.load_block_groups()
precincts = dept.load_police_precincts()
tracts = dept.load_census_tracts()
precincts.head()
# Out:
#                         slug             set           kind external_i  \
# 0  77th-street-lapd-division  LAPD Divisions  LAPD Division         12
# 1      central-lapd-division  LAPD Divisions  LAPD Division          1
# 2   devonshire-lapd-division  LAPD Divisions  LAPD Division         17
# 3     foothill-lapd-division  LAPD Divisions  LAPD Division         16
# 4       harbor-lapd-division  LAPD Divisions  LAPD Division          5
#
#           name                 display_na  \
# 0  77th Street  77th Street LAPD Division
# 1      Central      Central LAPD Division
# 2   Devonshire   Devonshire LAPD Division
# 3     Foothill     Foothill LAPD Division
# 4       Harbor       Harbor LAPD Division
#
#                                                  url number    phone_numb  \
# 0  http://www.lapdonline.org/77th_street_communit...     12  213-485-4164
# 1  http://www.lapdonline.org/central_community_po...      1  213-485-3294
# 2  http://www.lapdonline.org/devonshire_community...     17  818-832-0633
# 3  http://www.lapdonline.org/foothill_community_p...     16  818-756-8861
# 4  http://www.lapdonline.org/harbor_community_pol...      5  310-726-7700
#
#                      address  \
# 0           7600 S. Broadway
# 1             251 E. 6th St.
# 2        10250 Etiwanda Ave.
# 3          12760 Osborne St.
# 4  2175 John S. Gibson Blvd.
#
#                          ...                         RACE_NH_OTHER  \
# 0                        ...                            870.694270
# 1                        ...                            238.896974
# 2                        ...                            733.627030
# 3                        ...                            638.315695
# 4                        ...                            450.633662
#
#    RACE_NH_MULTIRACIAL  RACE_HISPANIC  POVERTY_TOTAL   POVERTY_BPL  \
# 0          1768.269866  103196.108821  178466.603994  54997.983164
# 1          1890.706219   15657.215214   54107.577791  19813.317814
# 2          6904.626033   69810.778569  223450.798257  23836.680790
# 3          2237.869971  124931.063478  190061.556495  36926.103431
# 4          4938.067878  112627.182346  180304.679827  38765.744715
#
#    POVERTY_NOT_BPL  EMPLOYMENT_TOTAL  EMPLOYMENT_EMPLOYED  \
# 0    123468.620830      81277.612528         70819.597526
# 1     34294.259978      29314.517019         26605.679738
# 2    199614.117467     121395.753742        112632.356647
# 3    153135.453064      96782.303394         86798.574242
# 4    141538.935112      91790.858253         82673.895206
#
#    EMPLOYMENT_UNEMPLOYED                                           geometry
# 0           10458.015002  POLYGON ((-118.3148948951553 34.00371678060566...
# 1            2708.837281  POLYGON ((-118.2243816590658 34.06850962588265...
# 2            8763.397095  POLYGON ((-118.4896378723103 34.31514263477411...
# 3            9983.729152  POLYGON ((-118.3829144583267 34.29425373977321...
# 4            9116.963048  POLYGON ((-118.2815067203804 33.86634772230949...
#
# [5 rows x 31 columns]

# %% [markdown]
# # Preprocess

# %%
raw_arrests.shape
# Out:
# (126855, 18)

# %%
'{:.2%}'.format(
    (raw_arrests['LOCATION_LATITUDE'] == '0').mean())
# Out:
# '5.32%'

# %%
raw_arrests.head().T
# Out:
#                                                          0  \
# INCIDENT_DATE                                    ARST DATE
# INCIDENT_TIME                                         TIME
# INCIDENT_UNIQUE_IDENTIFIER                          RPT_ID
# LOCATION_DISTRICT                                     AREA
# LOCATION_TYPE                                    AREA_DESC
# UNKNOWN_FIELD_TYPE                                      RD
# SUBJECT_AGE                                            AGE
# SUBJECT_GENDER                                      SEX_CD
# SUBJECT_RACE                                    DESCENT_CD
# UNKNOWN_FIELD_TYPE.1                           CHRG_GRP_CD
# INCIDENT_REASON                                   GRP_DESC
# UNKNOWN_FIELD_TYPE.2                           ARST_TYP_CD
# CHARGE                                              CHARGE
# CHARGE_DESCRIPTION                               CHRG_DESC
# LOCATION_FULL_STREET_ADDRESS_OR_INTERSECTION      LOCATION
# CROSS_STREET                                         CRSST
# LOCATION_LATITUDE                             Location Lat
# LOCATION_LONGITUDE                            Location Lon
#
#                                                                                      1  \
# INCIDENT_DATE                                                            12/31/15 0:00
# INCIDENT_TIME                                                                     2345
# INCIDENT_UNIQUE_IDENTIFIER                                                     4538991
# LOCATION_DISTRICT                                                                   14
# LOCATION_TYPE                                                                  Pacific
# UNKNOWN_FIELD_TYPE                                                                1435
# SUBJECT_AGE                                                                         43
# SUBJECT_GENDER                                                                       M
# SUBJECT_RACE                                                                         H
# UNKNOWN_FIELD_TYPE.1                                                                22
# INCIDENT_REASON                                                Driving Under Influence
# UNKNOWN_FIELD_TYPE.2                                                                 M
# CHARGE                                                                      23152(A)VC
# CHARGE_DESCRIPTION                                         DRUNK DRIVING ALCOHOL/DRUGS
# LOCATION_FULL_STREET_ADDRESS_OR_INTERSECTION   3500    MCLAUGHLIN                   AV
# CROSS_STREET                                                                       NaN
# LOCATION_LATITUDE                                                              34.0141
# LOCATION_LONGITUDE                                                           -118.4288
#
#                                                                                      2  \
# INCIDENT_DATE                                                            12/31/15 0:00
# INCIDENT_TIME                                                                     2330
# INCIDENT_UNIQUE_IDENTIFIER                                                     4538996
# LOCATION_DISTRICT                                                                    1
# LOCATION_TYPE                                                                  Central
# UNKNOWN_FIELD_TYPE                                                                 101
# SUBJECT_AGE                                                                         27
# SUBJECT_GENDER                                                                       M
# SUBJECT_RACE                                                                         W
# UNKNOWN_FIELD_TYPE.1                                                                 4
# INCIDENT_REASON                                                     Aggravated Assault
# UNKNOWN_FIELD_TYPE.2                                                                 F
# CHARGE                                                                      273.5(A)PC
# CHARGE_DESCRIPTION                            CORPORAL INJURY ON SPOUSE/COHABITANT/ETC
# LOCATION_FULL_STREET_ADDRESS_OR_INTERSECTION    900    FIGUEROA                     TR
# CROSS_STREET                                                                       NaN
# LOCATION_LATITUDE                                                              34.0663
# LOCATION_LONGITUDE                                                           -118.2441
#
#                                                                                      3  \
# INCIDENT_DATE                                                            12/31/15 0:00
# INCIDENT_TIME                                                                     2320
# INCIDENT_UNIQUE_IDENTIFIER                                                     4539142
# LOCATION_DISTRICT                                                                    6
# LOCATION_TYPE                                                                Hollywood
# UNKNOWN_FIELD_TYPE                                                                 646
# SUBJECT_AGE                                                                         31
# SUBJECT_GENDER                                                                       M
# SUBJECT_RACE                                                                         W
# UNKNOWN_FIELD_TYPE.1                                                                16
# INCIDENT_REASON                                                     Narcotic Drug Laws
# UNKNOWN_FIELD_TYPE.2                                                                 M
# CHARGE                                                                      11350(A)HS
# CHARGE_DESCRIPTION                                  POSSESSION OF CONTROLLED SUBSTANCE
# LOCATION_FULL_STREET_ADDRESS_OR_INTERSECTION   6300    HOLLYWOOD                    BL
# CROSS_STREET                                                                       NaN
# LOCATION_LATITUDE                                                              34.1016
# LOCATION_LONGITUDE                                                           -118.3267
#
#                                                                                      4
# INCIDENT_DATE                                                            12/31/15 0:00
# INCIDENT_TIME                                                                     2319
# INCIDENT_UNIQUE_IDENTIFIER                                                     4538947
# LOCATION_DISTRICT                                                                   21
# LOCATION_TYPE                                                                  Topanga
# UNKNOWN_FIELD_TYPE                                                                2189
# SUBJECT_AGE                                                                         28
# SUBJECT_GENDER                                                                       M
# SUBJECT_RACE                                                                         H
# UNKNOWN_FIELD_TYPE.1                                                                22
# INCIDENT_REASON                                                Driving Under Influence
# UNKNOWN_FIELD_TYPE.2                                                                 M
# CHARGE                                                                      23152(A)VC
# CHARGE_DESCRIPTION                                         DRUNK DRIVING ALCOHOL/DRUGS
# LOCATION_FULL_STREET_ADDRESS_OR_INTERSECTION           VENTURA                      FY
# CROSS_STREET                                                                  WINNETKA
# LOCATION_LATITUDE                                                              34.1723
# LOCATION_LONGITUDE                                                           -118.5709

# %%
variables = pandas.Series(raw_arrests.columns, index=raw_arrests.loc[0])
arrests = raw_arrests.loc[1:].copy()

# process date and drop time
arrests['INCIDENT_DATE'] = pandas.to_datetime(
    arrests['INCIDENT_DATE'], format='%m/%d/%y %H:%M')
arrests = arrests.drop('INCIDENT_TIME', axis=1)

# convert dtypes
numeric_columns = [
    'LOCATION_LATITUDE',
    'LOCATION_LONGITUDE',
]
arrests[numeric_columns] = arrests[numeric_columns].apply(pandas.to_numeric)

# drop entries where lat/lon is unknown
# (5.32% of the entries)
# (could have retrieved approximate lat/lon from address)
arrests = arrests[
    (arrests['LOCATION_LATITUDE'] != 0) &
    (arrests['LOCATION_LONGITUDE'] != 0)
]

# generate points from location
points = [shapely.geometry.Point(x, y)
          for x, y in zip(
              arrests['LOCATION_LONGITUDE'], arrests['LOCATION_LATITUDE'])]

# convert to GeoDataFrame
arrests = geopandas.GeoDataFrame(
    arrests,
    geometry=points,
    crs=util.crs.epsg4326,
)
arrests = arrests.to_crs(precincts.crs)

# %% [markdown]
# # EDA

# %%
arrests_sample = arrests.sample(2000, random_state=1)
arrests_sample_big = arrests.sample(10000, random_state=1)

# %%
print(" Precincts CRS: {}".format(precincts.crs))
print(" Arrests CRS: {}".format(arrests.crs))
print(" Tracts CRS: {}".format(tracts.crs))
print(" BGs CRS: {}".format(bgs.crs))
# Out:
#  Precincts CRS: {'init': 'epsg:4269'}
#  Arrests CRS: {'init': 'epsg:4269'}
#  Tracts CRS: {'init': 'epsg:4269'}
#  BGs CRS: {'init': 'epsg:4269'}

# %%
# only use intersecting regions
arrests_sample = arrests_sample[arrests_sample.intersects(precincts.unary_union)]
arrests_sample_big = arrests_sample_big[arrests_sample_big.intersects(precincts.unary_union)]
tracts = tracts[tracts.intersects(precincts.unary_union)]
bgs = bgs[bgs.intersects(precincts.unary_union)]

# set up equal-area projection
proj = util.crs.equal_area_from_geodf(tracts)
precincts = precincts.to_crs(proj)
arrests_sample = arrests_sample.to_crs(proj)
arrests_sample_big = arrests_sample_big.to_crs(proj)
tracts = tracts.to_crs(proj)
bgs = bgs.to_crs(proj)

# %%
def random_point(polygon):
    xmin, ymin, xmax, ymax = polygon.bounds
    x = numpy.random.uniform(xmin, xmax)
    y = numpy.random.uniform(ymin, ymax)
    point = shapely.geometry.Point(x, y)
    if polygon.contains(point):
        return point
    else:
        return random_point(polygon)
    
def random_points(polygon, count):
    return [random_point(polygon) for _ in range(count)]

def multiple_random_points(polygons, counts, random_state=None):
    if random_state is not None:
        numpy.random.seed(random_state)
        
    return [point
            for polygon, count in zip(polygons, counts)
            for point in random_points(polygon, count)]

# %%
polygons = precincts.geometry[:2]
polygons.plot()

# %%
points = multiple_random_points(polygons, [1000, 1000], 1)

matplotlib.pyplot.scatter(
    [p.x for p in points],
    [p.y for p in points],
    s=1,
)

# %%
df = bgs

geoms = df.geometry
white = df['RACE_NH_WHITE']
black = df['RACE_NH_BLACK']
asian = df['RACE_NH_ASIAN']
other = df['RACE_NH_INDIAN'] + df['RACE_NH_HAWAIIAN'] + df['RACE_NH_OTHER'] + df['RACE_NH_MULTIRACIAL']
hispanic = df['RACE_HISPANIC']

# %%
names = ['White', 'Black', 'Asian', 'Hispanic', 'Other']
colors = ['#73B2FF', '#55FF00', '#FF0000', '#FFAA00', '#895A44']
values = [white.sum(), black.sum(), asian.sum(), hispanic.sum(), other.sum()]

fig, ax = matplotlib.pyplot.subplots(figsize=(12, 8))
ax.bar(names, values, color=colors)
ax.set_title('Racial distribution for {}'.format(dept.full_name))
ax.set_xlabel('Race')
ax.set_ylabel('Population')
# Out:
# Text(0, 0.5, 'Population')

# %%
PlotPoint = collections.namedtuple('PlotPoint', 'x y color')

fig, ax = matplotlib.pyplot.subplots(figsize=(20, 20))

polygons = geoms
name_lst = ['White', 'Black', 'Asian', 'Hispanic']
counts_lst = [white, black, asian, hispanic]
color_lst = ['#a6cee3', '#1f78b4', '#b2df8a', '#33a02c']

total_points = []
for counts, color in zip(counts_lst, color_lst):
    counts = counts // 100
    points = multiple_random_points(polygons, counts)
    total_points += [PlotPoint(p.x, p.y, color) for p in points]
    
# must shuffle points, otherwise specified order starts to matter
numpy.random.shuffle(total_points)
    
# remove points outside police area
region = precincts.unary_union
total_points = [p
                for p in total_points
                if region.contains(shapely.geometry.Point(p.x, p.y))]

ax.scatter(
    [p.x for p in total_points],
    [p.y for p in total_points],
    c=[p.color for p in total_points],
    s=1,
    alpha=1,
)
precincts.plot(
    ax=ax,
    color='none',
    edgecolor=(0, 0, 0, 0.5)
)

legend_handles = [
    matplotlib.lines.Line2D([0], [0], marker='o', color='w', 
                            label=label, markerfacecolor=color, 
                            markersize=10) 
    for label, color in zip(name_lst, color_lst)
]
ax.legend(handles=legend_handles, loc='lower right')

ax.set_aspect('equal')
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)
ax.set_title('Racial dot map for {}'.format(dept.full_name));
